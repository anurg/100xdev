# %% [markdown]
# <a href="https://colab.research.google.com/github/anurg/100xdev/blob/main/pandas_labs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Pandas: For Data Analysis and Data Manipulations

#here we have 2 categories
#1.series(1-D data) :nothing but a column
#2.DataFrames(2-D Tabular data): Collection of Series(columns)

#creating a series
#creating a series from a list
import pandas as pd
x=[1,2,3,4,5]
z=pd.Series(x)
print(z)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64
